# %% [markdown]
# # 네이버 금융 뉴스 스크래핑 단독 실행
#
# `FinanceNewsScrapService.do_scraping()` 만 독립적으로 실행해 결과를 확인하는 용도입니다.

# %%
from app.core.utils.notebook import run_async
from app.modules.browser.playwright import PlaywrightManager
from app.services.scraper.finance_news import FinanceNewsScrapService

# %%
fns_service = FinanceNewsScrapService(PlaywrightManager())
run_async(fns_service.do_scraping())
